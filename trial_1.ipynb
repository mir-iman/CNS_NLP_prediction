# %%
#checking BOW
# !python -m models.bow \
  --target surv_mo_60 \
  --data-dir ./toy_data \
  --results-dir ./results \
  --epochs 3 \
  --imbalance-fix none
# Out:
# Training and evaluating a BoW model
# /Users/imanmir/Documents/CNS_NLP_prediction/trainers/bow_trainer.py:65: UserWarning: For our BoW models, epochs are simply re-training and evaluating our models each epoch
#   warnings.warn('For our BoW models, epochs are simply re-training and evaluating our models each epoch')
# /Users/imanmir/Documents/CNS_NLP_prediction/cancer_nlp/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
#         0   0/3      0.5         0.5      0.5     0.0      0.0     0.0         0
# ...

# %%
#checking cnn
# !python -m models.cnn \
  --target surv_mo_60 \
  --data-dir ./toy_data \
  --results-dir ./results \
  --epochs 3 \
  --imbalance-fix none
# Out:
# Training and evaluating a CNN model
# Using a CPU
# self.embed num_embeddings is: 4 while embedding_dim is 300
# Training epoch 1/3: 100%|█████████████████████████| 1/1 [00:00<00:00, 17.48it/s]
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
#         0   0/3      0.5         0.5      0.5     0.0      0.0     0.0     0.692
# Training epoch 2/3: 100%|█████████████████████████| 1/1 [00:00<00:00, 68.56it/s]
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
#         0   1/3      0.5         0.5      0.5     0.0      0.0     0.0     0.691
# Training epoch 3/3: 100%|█████████████████████████| 1/1 [00:00<00:00, 57.76it/s]
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
#         0   2/3      0.5         0.5      0.5     0.0      0.0     0.0      0.69
# Here are the results on our test split:
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
# ...

# %%
#checking lstm
# !python -m models.lstm \
  --target surv_mo_60 \
  --data-dir ./toy_data \
  --results-dir ./results \
  --epochs 3 \
  --imbalance-fix none
# Out:
# Training and evaluating a LSTM model
# Using a CPU
# self.embed num_embeddings is: 4 while embedding_dim is 300
# /Users/imanmir/Documents/CNS_NLP_prediction/cancer_nlp/lib/python3.14/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Applying weight drop of 0.3 to weight_hh_l0
# Training epoch 1/3: 100%|█████████████████████████| 1/1 [00:00<00:00,  9.11it/s]
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
#         0   0/3      0.5         0.5      0.5     0.0      0.0     0.0     0.694
# Training epoch 2/3: 100%|█████████████████████████| 1/1 [00:00<00:00, 14.23it/s]
#   Minutes Epoch  Dev/Acc  Dev/BalAcc  Dev/AUC  Dev/Pr  Dev/Rec  Dev/F1  Dev/Loss
#         0   1/3      0.5         0.5      0.5     0.0      0.0     0.0     0.694
# ...

# %%
#checking bert
# !python -m models.bert \
  --target surv_mo_60 \
  --data-dir ./toy_data \
  --results-dir ./results \
  --epochs 3 \
  --imbalance-fix none
# Out:
# Training and evaluating a BERT model
# Using a CPU
# ...
# 8it [00:00, 17623.13it/s]
# 4it [00:00, 83468.74it/s]
# 4it [00:00, 91180.52it/s]
# /Users/imanmir/Documents/CNS_NLP_prediction/cancer_nlp/lib/python3.14/site-packages/pytorch_lightning/utilities/parsing.py:213: Attribute 'loss_fn' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss_fn'])`.
# Loading weights: 100%|█████████████████████| 199/199 [00:00<00:00, 16160.36it/s]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# ...
